# %%
import torch 
from torch import nn 
from torch._jit_internal import weak_module, weak_script_method
from torch.nn import functional as F

# %%
# Out:
# <function nll_loss at 0x7f14ecf43d08>
