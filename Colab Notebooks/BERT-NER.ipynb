# %%
! wget https://h5y6sq.bn.files.1drv.com/y4msJGLPLhpnBZiWnX9taGDhGs3C38YEauiVW515klqA89qKrDTXSfR7Y9biZkJAKgGmzCxXv2D7o3wnVrrHC-llyNTM7xUXEe-MSa5IN_Vv5ofxbhT-p4N9OI-X6RopTsIYSBPHbGf4nSP9wBh39moj9ldodpcA9ayFYnDUeF7I6zauMQbq6hDPKaAcgZODvI9gZUq3Qj7uhnu2yfj2U_Xhg/large.zip?download&psid=1
# Out:
# --2019-11-06 23:36:13--  https://h5y6sq.bn.files.1drv.com/y4msJGLPLhpnBZiWnX9taGDhGs3C38YEauiVW515klqA89qKrDTXSfR7Y9biZkJAKgGmzCxXv2D7o3wnVrrHC-llyNTM7xUXEe-MSa5IN_Vv5ofxbhT-p4N9OI-X6RopTsIYSBPHbGf4nSP9wBh39moj9ldodpcA9ayFYnDUeF7I6zauMQbq6hDPKaAcgZODvI9gZUq3Qj7uhnu2yfj2U_Xhg/large.zip?download
# Resolving h5y6sq.bn.files.1drv.com (h5y6sq.bn.files.1drv.com)... 13.107.42.12
# Connecting to h5y6sq.bn.files.1drv.com (h5y6sq.bn.files.1drv.com)|13.107.42.12|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1238231609 (1.2G) [application/zip]
# Saving to: ‘large.zip?download’
#
# large.zip?download  100%[===================>]   1.15G  15.9MB/s    in 49s
#
# 2019-11-06 23:37:08 (24.0 MB/s) - ‘large.zip?download’ saved [1238231609/1238231609]

# %%
! mv large.zip?download large.zip

# %%
! unzip large.zip
# Out:
# Archive:  large.zip
#    creating: out_large/
#   inflating: out_large/vocab.txt
#   inflating: out_large/pytorch_model.bin
#   inflating: out_large/eval_results.txt
#   inflating: out_large/tokenizer_config.json
#   inflating: out_large/special_tokens_map.json
#   inflating: out_large/model_config.json
#  extracting: out_large/added_tokens.json
#   inflating: out_large/config.json

# %%
! wget https://github.com/kamalkraj/BERT-NER/archive/dev.zip
# Out:
# --2019-11-06 23:43:43--  https://github.com/kamalkraj/BERT-NER/archive/dev.zip
# Resolving github.com (github.com)... 140.82.118.3
# Connecting to github.com (github.com)|140.82.118.3|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://codeload.github.com/kamalkraj/BERT-NER/zip/dev [following]
# --2019-11-06 23:43:44--  https://codeload.github.com/kamalkraj/BERT-NER/zip/dev
# Resolving codeload.github.com (codeload.github.com)... 140.82.114.10
# Connecting to codeload.github.com (codeload.github.com)|140.82.114.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘dev.zip’
#
# dev.zip                 [   <=>              ]   1.61M  3.08MB/s    in 0.5s
#
# 2019-11-06 23:43:44 (3.08 MB/s) - ‘dev.zip’ saved [1684956]

# %%
! unzip dev.zip
# Out:
# Archive:  dev.zip
# f7324b0f3cd5eac66a8c3400ff291ac789760858
#    creating: BERT-NER-dev/
#   inflating: BERT-NER-dev/.gitignore
#   inflating: BERT-NER-dev/LICENSE.txt
#   inflating: BERT-NER-dev/README.md
#   inflating: BERT-NER-dev/api.py
#   inflating: BERT-NER-dev/bert.py
#    creating: BERT-NER-dev/cpp-app/
#   inflating: BERT-NER-dev/cpp-app/CMakeLists.txt
#   inflating: BERT-NER-dev/cpp-app/app.cpp
#    creating: BERT-NER-dev/cpp-app/unilib/
#   inflating: BERT-NER-dev/cpp-app/unilib/tokenizer.cpp
#   inflating: BERT-NER-dev/cpp-app/unilib/tokenizer.h
#   inflating: BERT-NER-dev/cpp-app/unilib/unicode.cpp
#   inflating: BERT-NER-dev/cpp-app/unilib/unicode.h
#   inflating: BERT-NER-dev/cpp-app/unilib/uninorms.cpp
#   inflating: BERT-NER-dev/cpp-app/unilib/uninorms.h
#   inflating: BERT-NER-dev/cpp-app/unilib/unistrip.cpp
#   inflating: BERT-NER-dev/cpp-app/unilib/unistrip.h
#   inflating: BERT-NER-dev/cpp-app/unilib/utf16.cpp
#   inflating: BERT-NER-dev/cpp-app/unilib/utf16.h
# ...

# %%
! mv BERT-NER-dev/*.py .

# %%
! mv BERT-NER-dev/*.txt .

# %%
! ls
# Out:
# api.py	      bert.py  large.zip    out_large	 requirements.txt  sample_data
# BERT-NER-dev  dev.zip  LICENSE.txt  __pycache__  run_ner.py

# %%
! pip3 install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 184kB 9.5MB/s
# ...
#      |████████████████████████████████| 748.9MB 20kB/s
# ...
#      |████████████████████████████████| 51kB 7.3MB/s
# ...
#      |████████████████████████████████| 1.5MB 54.1MB/s
# ...
#      |████████████████████████████████| 860kB 25.6MB/s
# ...
#      |████████████████████████████████| 645kB 47.2MB/s
# ...
#      |████████████████████████████████| 1.0MB 47.4MB/s
# ...
#   Created wheel for nltk: filename=nltk-3.4.5-cp36-none-any.whl size=1449908 sha256=a52b617e28c22be95f0982e970e5762e1ab064823e8f7c91d105593314e63f57
#   Stored in directory: /root/.cache/pip/wheels/96/86/f6/68ab24c23f207c0077381a5e3904b2815136b879538a24b483
# ...
#   Created wheel for sacremoses: filename=sacremoses-0.0.35-cp36-none-any.whl size=883999 sha256=358bc964bb3a8ba06f297f2d0627b464bddbb2b4f55d744d4744db6446729a85
#   Stored in directory: /root/.cache/pip/wheels/63/2a/db/63e2909042c634ef551d0d9ac825b2b0b32dede4a6d87ddc94
# Successfully built nltk sacremoses
# ...

# %%
from bert import *

# %%
! ls
# Out:
# api.py	      bert.py  large.zip    out_large	 requirements.txt  sample_data
# BERT-NER-dev  dev.zip  LICENSE.txt  __pycache__  run_ner.py

# %%
model = Ner("out_large/")

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
model.predict("India (Hindi: Bhārat), officially the Republic of India (Hindi: Bhārat Gaṇarājya),[19] is a country in South Asia. It is the seventh-largest country by area, the second-most populous country, and the most populous democracy in the world. Bounded by the Indian Ocean on the south, the Arabian Sea on the southwest, and the Bay of Bengal on the southeast, it shares land borders with Pakistan to the west;[e] China, Nepal, and Bhutan to the north; and Bangladesh and Myanmar to the east. In the Indian Ocean, India is in the vicinity of Sri Lanka and the Maldives; its Andaman and Nicobar Islands share a maritime border with Thailand and Indonesia.")
# Out:
# [{'confidence': 0.9998642206192017, 'tag': 'B-LOC', 'word': 'India'},
#  {'confidence': 0.9999786615371704, 'tag': 'O', 'word': '('},
#  {'confidence': 0.994716465473175, 'tag': 'B-MISC', 'word': 'Hindi'},
#  {'confidence': 0.9996907711029053, 'tag': 'O', 'word': ':'},
#  {'confidence': 0.8256627321243286, 'tag': 'B-LOC', 'word': 'Bhārat'},
#  {'confidence': 0.9999041557312012, 'tag': 'O', 'word': ')'},
#  {'confidence': 0.9999830722808838, 'tag': 'O', 'word': ','},
#  {'confidence': 0.9999462366104126, 'tag': 'O', 'word': 'officially'},
#  {'confidence': 0.9999624490737915, 'tag': 'O', 'word': 'the'},
#  {'confidence': 0.9956368803977966, 'tag': 'B-LOC', 'word': 'Republic'},
#  {'confidence': 0.9980159997940063, 'tag': 'I-LOC', 'word': 'of'},
#  {'confidence': 0.9989859461784363, 'tag': 'I-LOC', 'word': 'India'},
#  {'confidence': 0.9999709129333496, 'tag': 'O', 'word': '('},
#  {'confidence': 0.978158712387085, 'tag': 'B-MISC', 'word': 'Hindi'},
# ...
